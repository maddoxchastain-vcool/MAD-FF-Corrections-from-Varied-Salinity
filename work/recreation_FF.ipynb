# %% [markdown]
# # Recreating Original Formation Factor Calculations #
# Author: Maddox Chastain
#
# Summer 2026

# %% [markdown]
# This notebook has the purpose of recreating the calculations seen within the original FF (formation factor) spreadsheets for all study sites of IODP EXP501. By recreating these original calculations, I hope to be able to easily adjust them to the varied levels of salinity seen at each site.
